# %% [markdown]
# <a href="https://colab.research.google.com/github/kairin/getfrozen/blob/main/basic_install_with_flash_attn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !cat /etc/*release
# !git lfs install
# !python --version
# !nvidia-smi
# !wget https://github.com/Dao-AILab/flash-attention/releases/download/v2.6.3/flash_attn-2.6.3+cu123torch2.4cxx11abiTRUE-cp310-cp310-linux_x86_64.whl
# !pip install flash_attn-2.6.3+cu123torch2.4cxx11abiTRUE-cp310-cp310-linux_x86_64.whl
# !wget https://raw.githubusercontent.com/kairin/getfrozen/refs/heads/main/frozen.txt
# !pip install -r frozen.txt



# actually, the frozen.txt should be enough to recreate my current system.
# but we will still go ahead an install everything else below.
# it should tell you that you already have the latest version of everything.
# Out:
# DISTRIB_ID=Ubuntu
# DISTRIB_RELEASE=22.04
# DISTRIB_CODENAME=jammy
# DISTRIB_DESCRIPTION="Ubuntu 22.04.3 LTS"
# PRETTY_NAME="Ubuntu 22.04.3 LTS"
# NAME="Ubuntu"
# VERSION_ID="22.04"
# VERSION="22.04.3 LTS (Jammy Jellyfish)"
# VERSION_CODENAME=jammy
# ID=ubuntu
# ID_LIKE=debian
# HOME_URL="https://www.ubuntu.com/"
# SUPPORT_URL="https://help.ubuntu.com/"
# BUG_REPORT_URL="https://bugs.launchpad.net/ubuntu/"
# PRIVACY_POLICY_URL="https://www.ubuntu.com/legal/terms-and-policies/privacy-policy"
# UBUNTU_CODENAME=jammy
# Git LFS initialized.
# Python 3.10.12
# Fri Nov  1 15:20:49 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# ...

# %%
# !pip show flash_attn
# Out:
# Name: flash-attn
# Version: 2.6.3
# Summary: Flash Attention: Fast and Memory-Efficient Exact Attention
# Home-page: https://github.com/Dao-AILab/flash-attention
# Author: Tri Dao
# Author-email: tri@tridao.me
# License:
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: einops, torch
# Required-by:

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
